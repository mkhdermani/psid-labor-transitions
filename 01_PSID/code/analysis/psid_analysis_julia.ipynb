# %%
using DataFrames
using Plots
using ReadStat
using StatFiles

# Load the data
df = read_dta("D:/PSID_SHELF/01_PSID/data/PSIDSHELF_1968_2019_LONG.dta")

# Define variable labels (as provided)
var_labels = Dict(
    "ID" => "Unique ID [(ER30001*1000)+ER30002]",
    "YEAR" => "Survey year",
    "LINEAGE" => "Lineage, 1968 family ID [ER30001]",
    "PNUM" => "Person number [ER30002]",
    "FID" => "Family ID, wave-specific",
    "HHID" => "Household ID, wave-specific",
    "CURRENT" => "Ind is current member of fam unit?",
    "REL" => "Ind's relation to ref person",
    "RELX" => "Ind's relation to ref person, extended",
    "REFCOUPLE" => "Ind is a member of ref couple?",
    "SAMPLE" => "FU's sample membership [ER30001]",
    "SAMPLEP" => "Ind's sample person status [ER32006]",
    "NONRESPONSE" => "Ind's reason for nonresponse, wave-specific",
    "NONRESPONSEX" => "Ind's reason for nonresponse, wave-specific, extended",
    "DROPSTAT" => "FU's panel status after 1997 Census/SEO sample drop",
    "ELIG1997CDS" => "Ind was in a fam unit with an eligible child for 1997 CDS?",
    "RESPONDENT" => "FU's respondent who completed the interview",
    "RESPONDENTX" => "FU's respondent who completed the interview, extended",
    "FW" => "FU's longitudinal weight",
    "FWCROSS" => "FU's cross-sectional weight",
    "FWLATINCORE" => "FU's longitudinal weight (for Latino/core samples)",
    "FWLATINONLY" => "FU's longitudinal weight (for Latino sample only)",
    "IW" => "Ind's longitudinal weight",
    "IWCROSS" => "Ind's cross-sectional weight",
    "IWLATINCORE" => "Ind's longitudinal weight (for Latino/core samples)",
    "IWLATINONLY" => "Ind's longitudinal weight (for Latino sample only)",
    "STRATUM" => "Sample stratum (complex survey design) [ER31996]",
    "CLUSTER" => "Sample cluster (complex survey design) [ER31997]",
    "SEX" => "Ind's sex [ER32000]",
    "BIRTHYEAR" => "Ind's birth year, last reported",
    "BIRTHMONTH" => "Ind's birth month, last reported",
    "DEATHYEAR" => "Ind's death year, last reported or best estimate",
    "AGEREP" => "Ind's reported age at time of interview",
    "GEOSTATE" => "FU's current state of residence",
    "GEOSTATECHI" => "Ind's childhood state of residence, majority response",
    "GEOREGION" => "FU's current region of residence",
    "GEOREGIONCHI" => "Ind's childhood region of residence, majority response",
    "FAMSIZE" => "FU's total number of individuals",
    "FAMCHILD" => "FU's total number of children",
    "FAMMARSTAT" => "RP's marital status",
    "FAMPARTNERED" => "RP is living with a spouse/partner?",
    "FAMMARRIED" => "RP is legally married to a spouse?",
    "RACEMAJ" => "Ind's race/ethnicity, majority response, from first mention",
    "RACEMAJMM" => "Ind's race/ethnicity, majority response, from multi mention",
    "RACE" => "Ind's race",
    "RACEX" => "Ind's race/ethnicity, from first mention, extended",
    "RACERP" => "RP's race/ethnicity, from first mention",
    "RACESP" => "SP's race/ethnicity, from first mention",
    "RACEMM" => "Ind's race/ethnicity, from multi mention",
    "RACEMMX" => "Ind's race/ethnicity, from multi mention, extended",
    "RACEMMRP" => "RP's race/ethnicity, from multi mention",
    "RACEMMSP" => "SP's race/ethnicity, from multi mention",
    "RACE1MREP" => "Ind's reported race, mention 1",
    "RACE2MREP" => "Ind's reported race, mention 2",
    "RACE3MREP" => "Ind's reported race, mention 3",
    "RACE4MREP" => "Ind's reported race, mention 4",
    "ETHOSPANREP" => "Ind's reported ethnic origin, Spanish descent",
    "EDUYEAR" => "Ind's reported years of education",
    "EDUYEARRP" => "RP's years of education",
    "EDUYEARSP" => "SP's years of education",
    "EDUYEARRC" => "RP/SP's joint highest years of education",
    "EDUYEARMAX" => "Ind's years of education, max ever response",
    "EDUYEARMAXRP" => "RP's years of education, max ever response",
    "EDUYEARMAXSP" => "SP's years of education, max ever response",
    "EDUYEARMAXRC" => "RP/SP's joint highest years of education, max ever response",
    "EDULEVEL" => "Ind's highest level of education",
    "EDULEVELRP" => "RP's highest level of education",
    "EDULEVELSP" => "SP's highest level of education",
    "EDULEVELRC" => "RP/SP's joint highest level of education",
    "EDULEVELMAX" => "Ind's highest level of education, max ever response",
    "EDULEVELMAXRP" => "RP's highest level of education, max ever response",
    "EDULEVELMAXSP" => "SP's highest level of education, max ever response",
    "EDULEVELMAXRC" => "RP/SP's joint highest level of education, max ever response",
    "EDUCOMP" => "Ind's highest grade completed",
    "EDUHSGRAD" => "Ind graduated high school?",
    "EDUANYCOL" => "Ind entered college?",
    "EDUDEGREE" => "Ind's highest degree attained",
    "EDUFINST" => "Ind attended non-U.S. educ institution?",
    "EDUFDEGREE" => "Ind's highest non-U.S. degree attained",
    "INCFAMN" => "FU's total family income (nominal USD), tax year",
    "INCFAMR" => "FU's total family income (real USD 2022), tax year",
    "INCFAMFN" => "FU's total family income, fam size adj (nominal USD), tax year",
    "INCFAMFR" => "FU's total family income, fam size adj (real USD 2022), tax year",
    "EARNINDN" => "Ind's earnings (nominal USD), tax year",
    "EARNINDR" => "Ind's earnings (real USD 2022), tax year",
    "EARNINDFN" => "Ind's earnings, fam size adj (nominal USD), tax year",
    "EARNINDFR" => "Ind's earnings, fam size adj (real USD 2022), tax year",
    "EARNINDNRP" => "RP's earnings (nominal USD), tax year",
    "EARNINDRRP" => "RP's earnings (real USD 2022), tax year",
    "EARNINDFNRP" => "RP's earnings, fam size adj (nominal USD), tax year",
    "EARNINDFRRP" => "RP's earnings, fam size adj (real USD 2022), tax year",
    "EARNINDNSP" => "SP's earnings (nominal USD), tax year",
    "EARNINDRSP" => "SP's earnings (real USD 2022), tax year",
    "EARNINDFNSP" => "SP's earnings, fam size adj (nominal USD), tax year",
    "EARNINDFRSP" => "SP's earnings, fam size adj (real USD 2022), tax year",
    "EARNINDNRC" => "RP/SP's combined earnings (nominal USD), tax year",
    "EARNINDRRC" => "RP/SP's combined earnings (real USD 2022), tax year",
    "EARNINDFNRC" => "RP/SP's combined earnings, fam size adj (nominal USD), tax year",
    "EARNINDFRRC" => "RP/SP's combined earnings, fam size adj (real USD 2022), tax year",
    "EMPSTAT1M" => "Ind's employment status, mention 1",
    "EMPSTAT2M" => "Ind's employment status, mention 2",
    "EMPSTAT3M" => "Ind's employment status, mention 3",
    "EMPSTAT4M" => "Ind's employment status, mention 4",
    "INACTSTAT" => "Ind's current employment status",
    "INACTSTATX" => "Ind's current employment status, extended",
    "EMPINDX" => "Ind's employment status, extended",
    "EMPSTAT" => "Ind's current employment status",
    "EMPSTATY" => "Ind's employment status, in the last 12 months",
    "WAGEOCC1M" => "Ind's occupation, mention 1",
    "WAGEOCC2M" => "Ind's occupation, mention 2",
    "WAGEOCC3M" => "Ind's occupation, mention 3",
    "WAGEOCC4M" => "Ind's occupation, mention 4",
    "OCCUPIND" => "Ind's occupation",
    "OCCUPINDE" => "Ind's occupation, extended",
    "OCCUPDES" => "Ind's occupation description",
    "OCCUPDESX" => "Ind's occupation description, extended",
    "OCCUPM" => "Ind's occupation, major groups",
    "OCCUPMX" => "Ind's occupation, major groups, extended",
    "OCCUPMIC" => "Ind's occupation, minor groups",
    "OCCUPMICX" => "Ind's occupation, minor groups, extended",
    "OCCUPINF" => "Ind's occupation information",
    "OCCUPINFX" => "Ind's occupation information, extended",
    "INCWAGE1" => "Ind's wage income, mention 1",
    "INCWAGE2" => "Ind's wage income, mention 2",
    "INCWAGE3" => "Ind's wage income, mention 3",
    "INCWAGE4" => "Ind's wage income, mention 4",
    "INCWAGE" => "Ind's total wage income",
    "INCWAGEY" => "Ind's wage income in the last 12 months",
    "INCWAGEYB" => "Ind's wage income in the last 12 months, before taxes",
    "INCWAGEB" => "Ind's wage income, before taxes",
    "INCWAGEB1" => "Ind's wage income, mention 1, before taxes",
    "INCWAGEB2" => "Ind's wage income, mention 2, before taxes",
    "INCWAGEB3" => "Ind's wage income, mention 3, before taxes",
    "INCWAGEB4" => "Ind's wage income, mention 4, before taxes",
    "OCCWAGE" => "Ind's wage occupation",
    "OCCWAGEY" => "Ind's wage occupation, in the last 12 months",
    "OCCWAGEYB" => "Ind's wage occupation, in the last 12 months, before taxes",
    "OCCWAGEB" => "Ind's wage occupation, before taxes",
    "OCCWAGEB1" => "Ind's wage occupation, mention 1, before taxes",
    "OCCWAGEB2" => "Ind's wage occupation, mention 2, before taxes",
    "OCCWAGEB3" => "Ind's wage occupation, mention 3, before taxes",
    "OCCWAGEB4" => "Ind's wage occupation, mention 4, before taxes",
    "EMPLSTAT1" => "Ind's employment status, mention 1",
    "EMPLSTAT2" => "Ind's employment status, mention 2",
    "EMPLSTAT3" => "Ind's employment status, mention 3",
    "EMPLSTAT4" => "Ind's employment status, mention 4",
    "EMPLSTAT" => "Ind's current employment status",
    "EMPLSTATY" => "Ind's employment status, in the last 12 months",
    "EMPLSTATYB" => "Ind's employment status, in the last 12 months, before taxes",
    "EMPLSTATB" => "Ind's employment status, before taxes",
    "EMPLSTATB1" => "Ind's employment status, mention 1, before taxes",
    "EMPLSTATB2" => "Ind's employment status, mention 2, before taxes",
    "EMPLSTATB3" => "Ind's employment status, mention 3, before taxes",
    "EMPLSTATB4" => "Ind's employment status, mention 4, before taxes"
)

# Function to create plots with variable labels as titles
function plot_with_labels(df::DataFrame, var_labels::Dict{String, String}, output_dir::String)
    for var in names(df)
        if haskey(var_labels, var)
            label = var_labels[var]
            p = scatter(df[!, var], df[!, :y], title=label, xlabel=var, ylabel="y")
            savefig(joinpath(output_dir, "plot_$(var).png"))
        end
    end
end

# Specify the directory where you want to save the plots
output_dir = "D:\\PSID_SHELF\\01_PSID\\julia"

# Call the function to create and save plots
plot_with_labels(df, var_labels, output_dir)
